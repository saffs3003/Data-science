# %% [markdown]
# # **part A : Advanced Mathematical Expressions**

# %%
import math

# %% [markdown]
#  ### 1. Evaluate: $$f(x)= \pi x^3 + \log(x) + \sqrt{x^3}+ \tan(x)+ e^x$$
# #### given x=3

# %%
x=3
func_fx_1 = (math.pi * x**3) +math.log(x) + math.sqrt(x**3) + math.tan(x) + math.exp(x)
print(f"The result at x = {x} is: {func_fx_1}")
# Out:
# The result at x = 3 is: 111.06075673841255

# %% [markdown]
# ### 2. Evaluate :$$g(x)= \frac{   e^{2x}+ \cosh(x)}    {\sinh(x)+ \log_{10}x}+\sqrt[3]{x^{5}}-\tan^{-1}(x) $$
# #### given x=2

# %%
x=2

func_gx_2=(math.exp(2*x)+math.cosh(x)) /(math.sinh(x)+math.log10(x))+ ((x**5)**(1/3))-math.atan(x)
print(f"The result at x = {x} is: {func_gx_2}")
# Out:
# The result at x = 2 is: 16.925589766460266

# %% [markdown]
# ### 3. $$h(x)=\sin{2x}.cos(x)+\frac{\tan(x)}{cot(x)}+ e^{\sin(x)}+log_e(\cos(x))+x^{\pi}$$
# #### Given $x= \frac{\pi}{4}$

# %%
x= math.pi/4

func_px_3= (
    math.sin(2*x)*
    math.cos(x)+
    (math.tan(x)/(1/math.tan(x)))+
    math.exp(math.sin(x))+
    math.log(math.cos(x))+
    x**math.pi
)
print(f"The result at x = {x} is: {func_px_3}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 8
#       1 x_4= math.pi/4
#       3 func_px_3= (
#       4     math.sin(2*x)*
#       5     math.cos(x)+
#       6     (math.tan(x)/(1/math.tan(x)))+
#       7     math.exp(math.sin(x))+
# ----> 8     math.log(math.cos(x))+
#       9     x**math.pi
#      10 )
#      11 print(f"The result at x = {x} is: {func_px_3}")
#
# ValueError: math domain error

# %% [markdown]
# ### 4. $$p(x)= \sqrt[2]{e^{x}+ \sinh{2x}}+ \frac{ln(x^2 +1)}{\tanh(x)} + e{\sin(x)} + \ln(\cos(x))+ x^{\pi}$$
# #### given x=1.5

# %%
x_4=1.5
func_px_4=( (math.exp(x) + math.sinh(2*x))**(1/2) + 
(math.log(x**2+1)/math.tanh(x))+
math.exp(1)*math.sin(x)+
math.log(math.cos(x))+
x**(math.pi))
print(f"The result at x = {x} is: {func_px_4}")

# %% [markdown]
# ### 5. $$q(x)= \frac{\pi^{x} e^{2x}}{\sqrt[2]{\sinh(x)+\cosh(x)}} + \log_2(x+1) \tan(\frac{\pi x}{6})+ \sqrt[4]{x^{7}} -\sin^{-1}(x)$$
#
# #### given x= 0.5

# %%
x=0.5
func_qx_5=(((math.pi**x * math.exp(2*x))/(math.sinh(x)+math.cosh(x))**(1/2)+
           math.log2(x+1)* math.tan((math.pi * x)/6)+ (x**7)**4 -math.asin(x)))
print(f"The result at x = {x} is: {func_qx_5}")

# %% [markdown]
# ### 6. $$r(x)=( e^{x} + e^{-x})^{2} - 4\sinh^{2}(x) + \frac{ln(x!)}{\sqrt x} + \cos(x) . \sec(x) + \tanh^{-1}(\frac{x-2}{x}) $$
# #### given x

# %%
x=2.5
func_rx_6 =((math.exp(x)+ math.exp(-x))**2-
           4* (math.sinh(x)**2)+
           (math.log(x)*x-x/math.sqrt(x))+
           math.cos(x)*(1/math.cos(x))+
           math.atanh((x-2)/x)
    
)
print(f"The result at x = {x} is: {func_rx_6}")

# %% [markdown]
# ### 7. $$s(x) = \frac{\sin^{3}(x)+ \cos^{3}(x)}{\sin(x)+\cos(x)} + e^{\tan(x)} -\ln(\frac{1}{csc(x)})+\sinh(x)\csch(x) + \sqrt[2]{\pi x^{2}} $$
#
#  #### given  $$x=\frac{\pi}{6} $$

# %%
x=math.pi/6

func_sx_7=((math.sin(x)**2- (math.sin(x) *math.cos(x))+(math.cos(x)**2))+
      math.exp(math.tan(x))-
     math.log(math.sin(x))+
     math.sinh(x)/(1/math.sinh(x))+
     (math.pi*(x**2)**2))


print(f"The result at x = {x} is: {func_sx_7}")

# %% [markdown]
# ### 8. $$ t(x)= \sqrt[3]{e^{3x}+ \pi^{x}} + \frac{\cosh(2x)-1}{\sinh^{2}(x)} + \ln(\tan(\frac{\pi}{4} +\frac{x}{2}))+x^{\pi} -\cos^{-1}(\frac{1}{e}) $$
#
# #### Given $$x=1 $$

# %%
x=1

term1 = (math.exp(3*x) + math.pi**x)**(1/3)
term2 = (math.cosh(2*x) - 1) / (math.sinh(x)**2)
term3 = math.log(math.tan((math.pi/4) + (x/2)))
term4 = x**math.pi
term5 = math.acos(1/math.e)

t_x = term1 + term2 + term3 + term4 - term5

print(f"The result at x = {x} is: {t_x}")

# %% [markdown]
# ### 9. $$u(x)= e^{x^{2}}. \sin(\pi x)+ \frac{\ln(1+x^{2})}{\tanh(2x)} + \sqrt[2]{\cosh^{2}(x)-\sinh^{2}(x)} + \tan^{-1}(e^{x}) - \frac{\pi^{2} x }{e^{x}}$$
# #### Given x=0.8

# %%
x=0.8

term1=(math.exp(x**2))*math.sin(math.pi*x)
term2=(math.log(1+(x**2)))/math.tanh(2*x)
term3=(math.cosh(x)**2-math.sinh(x)**2)**(1/2)
term4=math.atan(math.exp(x))
term5= (math.pi**2*x)/math.exp(x)
func_ux_9=term1+term2+term3+term4-term5

print(f"The result at x = {x} is: {func_ux_9}")

# %% [markdown]
# ### 10. $$ v(x) = \frac{e^{sin(x)}+e^{cos(x)}}{2} + \ln(\sin(x) + cos(x)) + \sqrt[2]{\tan^{2}(x) +1} + \sinh^{-1}(x) - \cosh(\frac{x}{2}) + \frac{\pi x^{2}}{e} + \sec^{2}(x)-\tan^2(x) $$
#
# #### given $$ x=\frac{\pi}{3} $$

# %%
x=math.pi/3

term1=(math.exp(math.sin(x))+math.exp(math.cos(x)))/2
term2=math.log(math.sin(x)+math.cos(x))
term3= (math.tan(x)**2+1)**2
term4=math.asinh(x)
term5=math.cosh(x/2)
term6=(math.pi * x**1)/math.exp(1)
term7=(1/(math.cos(x)**2))
term8=math.tan(x)**2

func_vx_10=term1+term2+term3+term4-term5+term6+term7-term8
print(f"The result at x = {x} is: {func_vx_10}")
